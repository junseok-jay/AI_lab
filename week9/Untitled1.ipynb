# %% [markdown]
# <a href="https://colab.research.google.com/github/junseok-jay/AI_lab/blob/main/week9/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# License: BSD
# Author: Sasank Chilamkurthy

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
from PIL import Image
from tempfile import TemporaryDirectory

cudnn.benchmark = True
plt.ion()   # interactive mode

# %%
from google.colab import drive
import zipfile
import os

# Mount Google Drive
# drive.mount('/content/drive') # Google Drive mounting is not needed for /content/sample_data

# Define the zip file path
zip_file_path = '/content/drive/MyDrive/Colab Notebooks/AI_lab/week9/sample_computer_vision.zip'

# Define the extraction path
extraction_path = './data/sample_computer_vision'

# Create the extraction directory if it doesn't exist
os.makedirs(extraction_path, exist_ok=True)

# Read and extract the zip file
try:
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(extraction_path)
    print(f"Successfully extracted {zip_file_path} to {extraction_path}")
except FileNotFoundError:
    print(f"Error: The file '{zip_file_path}' was not found.")
except zipfile.BadZipFile:
    print(f"Error: The file '{zip_file_path}' is not a valid zip file or is corrupted.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Successfully extracted /content/drive/MyDrive/Colab Notebooks/AI_lab/week9/sample_computer_vision.zip to ./data/sample_computer_vision

# %%
# Data augmentation and normalization for training
# Just normalization for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

data_dir = '/content/data/sample_computer_vision/sample_computer_vision'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

# We want to be able to train our model on an `accelerator <https://pytorch.org/docs/stable/torch.html#accelerators>`__
# such as CUDA, MPS, MTIA, or XPU. If the current accelerator is available, we will use it. Otherwise, we use the CPU.

device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %%
def imshow(inp, title=None):
    """Display image for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    # Create a temporary directory to save training checkpoints
    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')

        torch.save(model.state_dict(), best_model_params_path)
        best_acc = 0.0

        for epoch in range(num_epochs):
            print(f'Epoch {epoch}/{num_epochs - 1}')
            print('-' * 10)

            # Each epoch has a training and validation phase
            for phase in ['train', 'val']:
                if phase == 'train':
                    model.train()  # Set model to training mode
                else:
                    model.eval()   # Set model to evaluate mode

                running_loss = 0.0
                running_corrects = 0

                # Iterate over data.
                for inputs, labels in dataloaders[phase]:
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)

                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    # statistics
                    running_loss += loss.item() * inputs.size(0)
                    running_corrects += torch.sum(preds == labels.data)
                if phase == 'train':
                    scheduler.step()

                epoch_loss = running_loss / dataset_sizes[phase]
                epoch_acc = running_corrects.double() / dataset_sizes[phase]

                print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

                # deep copy the model
                if phase == 'val' and epoch_acc > best_acc:
                    best_acc = epoch_acc
                    torch.save(model.state_dict(), best_model_params_path)

            print()

        time_elapsed = time.time() - since
        print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:4f}')

        # load best model weights
        model.load_state_dict(torch.load(best_model_params_path, weights_only=True))
    return model

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title(f'predicted: {class_names[preds[j]]}')
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
model_ft = models.resnet18(weights='IMAGENET1K_V1')
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to ``nn.Linear(num_ftrs, len(class_names))``.
model_ft.fc = nn.Linear(num_ftrs, 2)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 223MB/s]

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.5106 Acc: 0.7735
# val Loss: 0.1400 Acc: 0.9550
#
# Epoch 1/24
# ----------
# train Loss: 0.4760 Acc: 0.8034
# val Loss: 0.1493 Acc: 0.9400
#
# Epoch 2/24
# ----------
# train Loss: 0.4332 Acc: 0.8333
# val Loss: 0.2350 Acc: 0.9200
#
# Epoch 3/24
# ----------
# train Loss: 0.5327 Acc: 0.7954
# val Loss: 0.1463 Acc: 0.9650
#
# Epoch 4/24
# ----------
# train Loss: 0.4507 Acc: 0.8194
# val Loss: 0.2512 Acc: 0.9100
#
# Epoch 5/24
# ----------
# train Loss: 0.4501 Acc: 0.8263
# val Loss: 0.1283 Acc: 0.9600
#
# Epoch 6/24
# ----------
# train Loss: 0.4687 Acc: 0.8064
# val Loss: 0.1483 Acc: 0.9500
#
# Epoch 7/24
# ----------
# train Loss: 0.3010 Acc: 0.8693
# val Loss: 0.1087 Acc: 0.9650
#
# Epoch 8/24
# ----------
# train Loss: 0.3082 Acc: 0.8752
# val Loss: 0.1327 Acc: 0.9600
#
# Epoch 9/24
# ----------
# train Loss: 0.2783 Acc: 0.8822
# val Loss: 0.1094 Acc: 0.9650
#
# Epoch 10/24
# ----------
# train Loss: 0.2981 Acc: 0.8762
# val Loss: 0.1198 Acc: 0.9550
#
# Epoch 11/24
# ----------
# train Loss: 0.2654 Acc: 0.8852
# val Loss: 0.1003 Acc: 0.9750
#
# Epoch 12/24
# ----------
# train Loss: 0.3010 Acc: 0.8583
# val Loss: 0.1004 Acc: 0.9750
#
# Epoch 13/24
# ----------
# train Loss: 0.2577 Acc: 0.8902
# val Loss: 0.1019 Acc: 0.9700
#
# Epoch 14/24
# ----------
# train Loss: 0.2509 Acc: 0.8902
# val Loss: 0.0933 Acc: 0.9700
#
# Epoch 15/24
# ----------
# train Loss: 0.2669 Acc: 0.8782
# val Loss: 0.0877 Acc: 0.9800
#
# Epoch 16/24
# ----------
# train Loss: 0.2623 Acc: 0.8952
# val Loss: 0.1041 Acc: 0.9600
#
# Epoch 17/24
# ----------
# train Loss: 0.2629 Acc: 0.8902
# val Loss: 0.0850 Acc: 0.9800
#
# Epoch 18/24
# ----------
# train Loss: 0.2229 Acc: 0.9042
# val Loss: 0.0878 Acc: 0.9750
#
# Epoch 19/24
# ----------
# train Loss: 0.2743 Acc: 0.8733
# val Loss: 0.0895 Acc: 0.9750
#
# Epoch 20/24
# ----------
# train Loss: 0.2794 Acc: 0.8832
# val Loss: 0.1301 Acc: 0.9700
#
# Epoch 21/24
# ----------
# train Loss: 0.2750 Acc: 0.8852
# val Loss: 0.0977 Acc: 0.9700
#
# Epoch 22/24
# ----------
# train Loss: 0.2572 Acc: 0.8932
# val Loss: 0.0851 Acc: 0.9800
#
# Epoch 23/24
# ----------
# train Loss: 0.2758 Acc: 0.8912
# val Loss: 0.0905 Acc: 0.9750
#
# Epoch 24/24
# ----------
# train Loss: 0.2510 Acc: 0.8932
# val Loss: 0.1335 Acc: 0.9500
#
# Training complete in 3m 10s
# Best val Acc: 0.980000

# %%
visualize_model(model_ft)

# %%
model_conv = torchvision.models.resnet18(weights='IMAGENET1K_V1')
for param in model_conv.parameters():
    param.requires_grad = False

# Parameters of newly constructed modules have requires_grad=True by default
num_ftrs = model_conv.fc.in_features
model_conv.fc = nn.Linear(num_ftrs, 2)

model_conv = model_conv.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that only parameters of final layer are being optimized as
# opposed to before.
optimizer_conv = optim.SGD(model_conv.fc.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=7, gamma=0.1)

# %%
model_conv = train_model(model_conv, criterion, optimizer_conv,
                         exp_lr_scheduler, num_epochs=100)
# Out:
# Epoch 0/99
# ----------
# train Loss: 0.3215 Acc: 0.8603
# val Loss: 0.1191 Acc: 0.9650
#
# Epoch 1/99
# ----------
# train Loss: 0.3329 Acc: 0.8483
# val Loss: 0.1027 Acc: 0.9850
#
# Epoch 2/99
# ----------
# train Loss: 0.3365 Acc: 0.8543
# val Loss: 0.1108 Acc: 0.9800
#
# Epoch 3/99
# ----------
# train Loss: 0.3384 Acc: 0.8513
# val Loss: 0.1261 Acc: 0.9650
#
# Epoch 4/99
# ----------
# train Loss: 0.3345 Acc: 0.8493
# val Loss: 0.1343 Acc: 0.9600
#
# Epoch 5/99
# ----------
# train Loss: 0.3628 Acc: 0.8483
# val Loss: 0.1063 Acc: 0.9800
#
# Epoch 6/99
# ----------
# train Loss: 0.2881 Acc: 0.8733
# val Loss: 0.1255 Acc: 0.9650
#
# Epoch 7/99
# ----------
# train Loss: 0.3239 Acc: 0.8523
# val Loss: 0.1038 Acc: 0.9800
#
# Epoch 8/99
# ----------
# train Loss: 0.3553 Acc: 0.8363
# val Loss: 0.1100 Acc: 0.9700
#
# Epoch 9/99
# ----------
# train Loss: 0.3392 Acc: 0.8483
# val Loss: 0.1586 Acc: 0.9400
#
# Epoch 10/99
# ----------
# train Loss: 0.3314 Acc: 0.8583
# val Loss: 0.1140 Acc: 0.9700
#
# Epoch 11/99
# ----------
# train Loss: 0.3365 Acc: 0.8523
# val Loss: 0.1148 Acc: 0.9750
#
# Epoch 12/99
# ----------
# train Loss: 0.3036 Acc: 0.8723
# val Loss: 0.1223 Acc: 0.9700
#
# Epoch 13/99
# ----------
# train Loss: 0.2937 Acc: 0.8772
# val Loss: 0.1116 Acc: 0.9700
#
# Epoch 14/99
# ----------
# train Loss: 0.3599 Acc: 0.8493
# val Loss: 0.1676 Acc: 0.9450
#
# Epoch 15/99
# ----------
# train Loss: 0.3164 Acc: 0.8563
# val Loss: 0.1225 Acc: 0.9700
#
# Epoch 16/99
# ----------
# train Loss: 0.3074 Acc: 0.8703
# val Loss: 0.1271 Acc: 0.9650
#
# Epoch 17/99
# ----------
# train Loss: 0.3459 Acc: 0.8373
# val Loss: 0.1203 Acc: 0.9650
#
# Epoch 18/99
# ----------
# train Loss: 0.3505 Acc: 0.8403
# val Loss: 0.1323 Acc: 0.9500
#
# Epoch 19/99
# ----------
# train Loss: 0.3525 Acc: 0.8543
# val Loss: 0.1113 Acc: 0.9750
#
# Epoch 20/99
# ----------
# train Loss: 0.3376 Acc: 0.8533
# val Loss: 0.1136 Acc: 0.9700
#
# Epoch 21/99
# ----------
# train Loss: 0.2824 Acc: 0.8782
# val Loss: 0.1456 Acc: 0.9500
#
# Epoch 22/99
# ----------
# train Loss: 0.3445 Acc: 0.8483
# val Loss: 0.1648 Acc: 0.9300
#
# Epoch 23/99
# ----------
# train Loss: 0.3090 Acc: 0.8573
# val Loss: 0.1114 Acc: 0.9700
#
# Epoch 24/99
# ----------
# train Loss: 0.3771 Acc: 0.8383
# val Loss: 0.1080 Acc: 0.9800
#
# Epoch 25/99
# ----------
# train Loss: 0.3501 Acc: 0.8403
# val Loss: 0.1259 Acc: 0.9600
#
# Epoch 26/99
# ----------
# train Loss: 0.3070 Acc: 0.8593
# val Loss: 0.1221 Acc: 0.9650
#
# Epoch 27/99
# ----------
# train Loss: 0.2951 Acc: 0.8633
# val Loss: 0.1198 Acc: 0.9650
#
# Epoch 28/99
# ----------
# train Loss: 0.3220 Acc: 0.8633
# val Loss: 0.1092 Acc: 0.9700
#
# Epoch 29/99
# ----------
# train Loss: 0.3298 Acc: 0.8533
# val Loss: 0.1064 Acc: 0.9650
#
# Epoch 30/99
# ----------
# train Loss: 0.3319 Acc: 0.8653
# val Loss: 0.1343 Acc: 0.9550
#
# Epoch 31/99
# ----------
# train Loss: 0.3216 Acc: 0.8593
# val Loss: 0.1170 Acc: 0.9750
#
# Epoch 32/99
# ----------
# train Loss: 0.3132 Acc: 0.8473
# val Loss: 0.1063 Acc: 0.9800
#
# Epoch 33/99
# ----------
# train Loss: 0.3072 Acc: 0.8703
# val Loss: 0.1220 Acc: 0.9650
#
# Epoch 34/99
# ----------
# train Loss: 0.3301 Acc: 0.8453
# val Loss: 0.1467 Acc: 0.9450
#
# Epoch 35/99
# ----------
# train Loss: 0.3277 Acc: 0.8593
# val Loss: 0.1243 Acc: 0.9700
#
# Epoch 36/99
# ----------
# train Loss: 0.3606 Acc: 0.8293
# val Loss: 0.1210 Acc: 0.9750
#
# Epoch 37/99
# ----------
# train Loss: 0.3425 Acc: 0.8413
# val Loss: 0.1103 Acc: 0.9700
#
# Epoch 38/99
# ----------
# train Loss: 0.3216 Acc: 0.8573
# val Loss: 0.1212 Acc: 0.9750
#
# Epoch 39/99
# ----------
# train Loss: 0.3615 Acc: 0.8293
# val Loss: 0.1138 Acc: 0.9700
#
# Epoch 40/99
# ----------
# train Loss: 0.3097 Acc: 0.8693
# val Loss: 0.1221 Acc: 0.9700
#
# Epoch 41/99
# ----------
# train Loss: 0.3556 Acc: 0.8363
# val Loss: 0.1217 Acc: 0.9650
#
# Epoch 42/99
# ----------
# train Loss: 0.3179 Acc: 0.8663
# val Loss: 0.1337 Acc: 0.9600
#
# Epoch 43/99
# ----------
# train Loss: 0.2813 Acc: 0.8842
# val Loss: 0.1358 Acc: 0.9600
#
# Epoch 44/99
# ----------
# train Loss: 0.3549 Acc: 0.8383
# val Loss: 0.1111 Acc: 0.9800
#
# Epoch 45/99
# ----------
# train Loss: 0.3317 Acc: 0.8653
# val Loss: 0.1081 Acc: 0.9700
#
# Epoch 46/99
# ----------
# train Loss: 0.3792 Acc: 0.8443
# val Loss: 0.1126 Acc: 0.9650
#
# Epoch 47/99
# ----------
# train Loss: 0.3391 Acc: 0.8513
# val Loss: 0.1152 Acc: 0.9750
#
# Epoch 48/99
# ----------
# train Loss: 0.3444 Acc: 0.8413
# val Loss: 0.1162 Acc: 0.9700
#
# Epoch 49/99
# ----------
# train Loss: 0.2892 Acc: 0.8743
# val Loss: 0.1186 Acc: 0.9650
#
# Epoch 50/99
# ----------
# train Loss: 0.3320 Acc: 0.8563
# val Loss: 0.1058 Acc: 0.9800
#
# Epoch 51/99
# ----------
# train Loss: 0.3284 Acc: 0.8513
# val Loss: 0.1209 Acc: 0.9800
#
# Epoch 52/99
# ----------
# train Loss: 0.3229 Acc: 0.8573
# val Loss: 0.1115 Acc: 0.9750
#
# Epoch 53/99
# ----------
# train Loss: 0.2997 Acc: 0.8653
# val Loss: 0.1072 Acc: 0.9800
#
# Epoch 54/99
# ----------
# train Loss: 0.3517 Acc: 0.8513
# val Loss: 0.1217 Acc: 0.9700
#
# Epoch 55/99
# ----------
# train Loss: 0.3012 Acc: 0.8812
# val Loss: 0.1257 Acc: 0.9600
#
# Epoch 56/99
# ----------
# train Loss: 0.3293 Acc: 0.8553
# val Loss: 0.1324 Acc: 0.9550
#
# Epoch 57/99
# ----------
# train Loss: 0.3489 Acc: 0.8363
# val Loss: 0.1112 Acc: 0.9700
#
# Epoch 58/99
# ----------
# train Loss: 0.3239 Acc: 0.8463
# val Loss: 0.1131 Acc: 0.9800
#
# Epoch 59/99
# ----------
# train Loss: 0.3388 Acc: 0.8533
# val Loss: 0.1125 Acc: 0.9800
#
# Epoch 60/99
# ----------
# train Loss: 0.3601 Acc: 0.8353
# val Loss: 0.1836 Acc: 0.9350
#
# Epoch 61/99
# ----------
# train Loss: 0.3399 Acc: 0.8473
# val Loss: 0.1506 Acc: 0.9400
#
# Epoch 62/99
# ----------
# train Loss: 0.3332 Acc: 0.8653
# val Loss: 0.1116 Acc: 0.9700
#
# Epoch 63/99
# ----------
# train Loss: 0.3014 Acc: 0.8653
# val Loss: 0.1611 Acc: 0.9400
#
# Epoch 64/99
# ----------
# train Loss: 0.2963 Acc: 0.8513
# val Loss: 0.1305 Acc: 0.9550
#
# Epoch 65/99
# ----------
# train Loss: 0.3115 Acc: 0.8553
# val Loss: 0.1128 Acc: 0.9700
#
# Epoch 66/99
# ----------
# train Loss: 0.3483 Acc: 0.8463
# val Loss: 0.1071 Acc: 0.9700
#
# Epoch 67/99
# ----------
# train Loss: 0.3654 Acc: 0.8353
# val Loss: 0.1263 Acc: 0.9700
#
# Epoch 68/99
# ----------
# train Loss: 0.3488 Acc: 0.8513
# val Loss: 0.1181 Acc: 0.9800
#
# Epoch 69/99
# ----------
# train Loss: 0.3126 Acc: 0.8553
# val Loss: 0.1233 Acc: 0.9650
#
# Epoch 70/99
# ----------
# train Loss: 0.3536 Acc: 0.8323
# val Loss: 0.1031 Acc: 0.9850
#
# Epoch 71/99
# ----------
# train Loss: 0.3080 Acc: 0.8563
# val Loss: 0.1038 Acc: 0.9750
#
# Epoch 72/99
# ----------
# train Loss: 0.3245 Acc: 0.8673
# val Loss: 0.1134 Acc: 0.9650
#
# Epoch 73/99
# ----------
# train Loss: 0.3006 Acc: 0.8633
# val Loss: 0.1270 Acc: 0.9600
#
# Epoch 74/99
# ----------
# train Loss: 0.2985 Acc: 0.8673
# val Loss: 0.1086 Acc: 0.9750
#
# Epoch 75/99
# ----------
# train Loss: 0.3272 Acc: 0.8573
# val Loss: 0.1135 Acc: 0.9700
#
# Epoch 76/99
# ----------
# train Loss: 0.3436 Acc: 0.8373
# val Loss: 0.1185 Acc: 0.9700
#
# Epoch 77/99
# ----------
# train Loss: 0.3332 Acc: 0.8613
# val Loss: 0.1329 Acc: 0.9550
#
# Epoch 78/99
# ----------
# train Loss: 0.3288 Acc: 0.8643
# val Loss: 0.1215 Acc: 0.9650
#
# Epoch 79/99
# ----------
# train Loss: 0.2779 Acc: 0.8752
# val Loss: 0.1161 Acc: 0.9750
#
# Epoch 80/99
# ----------
# train Loss: 0.3313 Acc: 0.8453
# val Loss: 0.1209 Acc: 0.9600
#
# Epoch 81/99
# ----------
# train Loss: 0.3558 Acc: 0.8483
# val Loss: 0.1176 Acc: 0.9800
#
# Epoch 82/99
# ----------
# train Loss: 0.3197 Acc: 0.8603
# val Loss: 0.1131 Acc: 0.9750
#
# Epoch 83/99
# ----------
# train Loss: 0.3125 Acc: 0.8703
# val Loss: 0.1095 Acc: 0.9850
#
# Epoch 84/99
# ----------
# train Loss: 0.3021 Acc: 0.8693
# val Loss: 0.1475 Acc: 0.9500
#
# Epoch 85/99
# ----------
# train Loss: 0.3287 Acc: 0.8533
# val Loss: 0.1221 Acc: 0.9600
#
# Epoch 86/99
# ----------
# train Loss: 0.3640 Acc: 0.8463
# val Loss: 0.1141 Acc: 0.9750
#
# Epoch 87/99
# ----------
# train Loss: 0.3251 Acc: 0.8483
# val Loss: 0.1099 Acc: 0.9700
#
# Epoch 88/99
# ----------
# train Loss: 0.3199 Acc: 0.8673
# val Loss: 0.1174 Acc: 0.9700
#
# Epoch 89/99
# ----------
# train Loss: 0.3546 Acc: 0.8413
# val Loss: 0.1083 Acc: 0.9850
#
# Epoch 90/99
# ----------
# train Loss: 0.3548 Acc: 0.8453
# val Loss: 0.1106 Acc: 0.9750
#
# Epoch 91/99
# ----------
# train Loss: 0.3426 Acc: 0.8353
# val Loss: 0.1103 Acc: 0.9750
#
# Epoch 92/99
# ----------
# train Loss: 0.3222 Acc: 0.8583
# val Loss: 0.1068 Acc: 0.9900
#
# Epoch 93/99
# ----------
# train Loss: 0.3624 Acc: 0.8154
# val Loss: 0.1111 Acc: 0.9650
#
# Epoch 94/99
# ----------
# train Loss: 0.3123 Acc: 0.8713
# val Loss: 0.1241 Acc: 0.9550
#
# Epoch 95/99
# ----------
# train Loss: 0.3000 Acc: 0.8663
# val Loss: 0.1160 Acc: 0.9750
#
# Epoch 96/99
# ----------
# train Loss: 0.3407 Acc: 0.8423
# val Loss: 0.1152 Acc: 0.9700
#
# Epoch 97/99
# ----------
# train Loss: 0.3346 Acc: 0.8453
# val Loss: 0.1066 Acc: 0.9750
#
# Epoch 98/99
# ----------
# train Loss: 0.3360 Acc: 0.8543
# val Loss: 0.1080 Acc: 0.9800
#
# Epoch 99/99
# ----------
# train Loss: 0.3575 Acc: 0.8403
# val Loss: 0.1236 Acc: 0.9700
#
# Training complete in 9m 54s
# Best val Acc: 0.990000

# %%
def visualize_model_predictions(model,img_path):
    was_training = model.training
    model.eval()

    img = Image.open(img_path)
    img = data_transforms['val'](img)
    img = img.unsqueeze(0)
    img = img.to(device)

    with torch.no_grad():
        outputs = model(img)
        _, preds = torch.max(outputs, 1)

        ax = plt.subplot(2,2,1)
        ax.axis('off')
        ax.set_title(f'Predicted: {class_names[preds[0]]}')
        imshow(img.cpu().data[0])

        model.train(mode=was_training)

# %%
visualize_model_predictions(
    model_conv,
    img_path='/content/data/sample_computer_vision/sample_computer_vision/val/dogs/dog.4021.jpg'
)

plt.ioff()
plt.show()
